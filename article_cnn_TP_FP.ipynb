# %%
import logging
import os
import sys
import pickle
import time

import pandas as pd
import torch
from torch import nn
from torch.nn import functional as F
from torch import optim
from torch.autograd import Variable
from tqdm import tqdm


from sklearn.metrics import accuracy_score


# test = pd.read_csv(r"corpus\imdb\testData.tsv", header=0, delimiter="\t", quoting=3)


num_epochs = 120
embed_size = 300
num_filter = 16
filter_size = 3
bidirectional = True
batch_size = 64
labels = 2
lr = 0.01
device = torch.device('cuda:0')
use_gpu = True


# cnn和transformer还挺像的，
# cnn应该代表的是基于词向量（定长输入）的类注意力机制

class SentimentNet(nn.Module):
    def __init__(self, embed_size, num_filter, filter_size, weight, labels, use_gpu, **kwargs):
        super(SentimentNet, self).__init__(**kwargs)

        self.use_gpu = use_gpu
        # 话说这个不会是我前面做的单词到词向量的映射表吧？？ 答：不用怀疑，正是
        self.embedding = nn.Embedding.from_pretrained(weight)
        # 防止嵌入层在训练中更新
        self.embedding.weight.requires_grad = False

        # 啥玩意儿这是？
        self.conv1d = nn.Conv1d(embed_size, num_filter, filter_size, padding=1)
        self.activate = F.relu
        self.decoder = nn.Linear(num_filter, labels)


    def forward(self, inputs):
        embeddings = self.embedding(inputs)
        # print(embeddings.shape)
        convolution = self.activate(self.conv1d(embeddings.permute([0, 2, 1])))
        # print(convolution.shape)

        pooling = F.max_pool1d(convolution, kernel_size=convolution.shape[2])

        outputs = self.decoder(pooling.squeeze(dim=2))
        # print(outputs)
        # print(self.decoder)

        return outputs

# %%
program = os.path.basename(sys.argv[0])
logger = logging.getLogger(program)

logging.basicConfig(format='%(asctime)s: %(levelname)s: %(message)s')
logging.root.setLevel(level=logging.INFO)
logger.info(r"running %s" % ''.join(sys.argv))

logging.info('loading data...')
# Out:
# 2024-04-17 08:43:54,791: INFO: running D:\SoftWare\Anaconda\envs\pytorch\lib\site-packages\ipykernel_launcher.py-fC:\Users\FlashBlack7\AppData\Roaming\jupyter\runtime\kernel-071685b8-b0ef-4def-8f26-3b4ef65b23fe.json
# 2024-04-17 08:43:54,792: INFO: loading data...

# %%
pickle_file = 'depression_glove_42B_300d_TP_FP.pkl'
[train_features, train_labels, val_features, val_labels, test_features, weight, word_to_idx, idx_to_word, vocab] = pickle.load(open(pickle_file, 'rb'))

# %%
net = SentimentNet(embed_size=embed_size, num_filter=num_filter, filter_size=filter_size,weight=weight, labels=labels, use_gpu=use_gpu)
net.to(device)
loss_function = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=lr)
train_set = torch.utils.data.TensorDataset(train_features, train_labels)
val_set = torch.utils.data.TensorDataset(val_features, val_labels)
test_set = torch.utils.data.TensorDataset(test_features, )

train_iter = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=True)
val_iter = torch.utils.data.DataLoader(val_set, batch_size=batch_size, shuffle=False)
test_iter = torch.utils.data.DataLoader(test_set, batch_size=batch_size, shuffle=False)

# %%
for epoch in range(num_epochs):
    start = time.time()
    train_loss, val_losses = 0, 0
    train_acc, val_acc = 0, 0
    n, m = 0, 0
    with tqdm(total=len(train_iter), desc='Epoch %d' % epoch) as pbar:
        for feature, label in train_iter:
            n += 1
            net.zero_grad()
            feature = Variable(feature.cuda())
            label = Variable(label.cuda())
            score = net(feature)
            loss = loss_function(score, label)
            loss.backward()
            optimizer.step()
            train_acc += accuracy_score(torch.argmax(score.cpu().data,dim=1), label.cpu())
            # print(label.shape)
            # print(torch.argmax(score.cpu().data,dim=1).shape)
            # exit(0)
            train_loss += loss

            pbar.set_postfix({'epoch': '%d' % (epoch),
                                  'train loss': '%.4f' % (train_loss.data / n),
                                  'train acc': '%.2f' % (train_acc / n)
                                  })
            pbar.update(1)

        with torch.no_grad():
            for val_feature, val_label in val_iter:
                m += 1
                val_feature = val_feature.cuda()
                val_label = val_label.cuda()
                val_score = net(val_feature)
                val_loss = loss_function(val_score, val_label)
                val_acc += accuracy_score(torch.argmax(val_score.cpu().data, dim=1), val_label.cpu())
                val_losses += val_loss
        end = time.time()
        runtime = end - start
        pbar.set_postfix({'epoch': '%d' % (epoch),
                              'train loss': '%.4f' % (train_loss.data / n),
                              'train acc': '%.2f' % (train_acc / n),
                              'val loss': '%.4f' % (val_losses.data / m),
                              'val acc': '%.2f' % (val_acc / m),
                              'time': '%.2f' % (runtime)})

        # tqdm.write('{epoch: %d, train loss: %.4f, train acc: %.2f, val loss: %.4f, val acc: %.2f, time: %.2f}' %
        #       (epoch, train_loss.data / n, train_acc / n, val_losses.data / m, val_acc / m, runtime))

test_pred = []
with torch.no_grad():
    with tqdm(total=len(test_iter), desc='Prediction') as pbar:
        for test_feature, in test_iter:
                test_feature = test_feature.cuda()
                test_score = net(test_feature)
                # test_pred.extent
                test_pred.extend(torch.argmax(test_score.cpu().data, dim=1).numpy().tolist())
                pbar.update(1)

# result_output = pd.DataFrame(data={"id": test["id"], "sentiment": test_pred})
# result_output.to_csv("./result/cnn.csv", index=False, quoting=3)
# logging.info('result saved!')
# Out:
# Epoch 0: 100%|██████████| 5/5 [00:00<00:00, 105.74it/s, epoch=0, train loss=0.6190, train acc=0.71, val loss=0.4147, val acc=0.98, time=0.05]
# Epoch 1: 100%|██████████| 5/5 [00:00<00:00, 111.33it/s, epoch=1, train loss=0.3548, train acc=0.97, val loss=0.2714, val acc=0.98, time=0.04]
# Epoch 2: 100%|██████████| 5/5 [00:00<00:00, 112.85it/s, epoch=2, train loss=0.2641, train acc=0.96, val loss=0.2014, val acc=0.98, time=0.05]
# Epoch 3: 100%|██████████| 5/5 [00:00<00:00, 109.94it/s, epoch=3, train loss=0.2029, train acc=0.97, val loss=0.1590, val acc=0.98, time=0.04]
# Epoch 4: 100%|██████████| 5/5 [00:00<00:00, 120.55it/s, epoch=4, train loss=0.1693, train acc=0.97, val loss=0.1338, val acc=0.98, time=0.04]
# Epoch 5: 100%|██████████| 5/5 [00:00<00:00, 131.92it/s, epoch=5, train loss=0.1522, train acc=0.97, val loss=0.1183, val acc=0.98, time=0.04]
# Epoch 6: 100%|██████████| 5/5 [00:00<00:00, 124.69it/s, epoch=6, train loss=0.1482, train acc=0.97, val loss=0.1091, val acc=0.98, time=0.04]
# Epoch 7: 100%|██████████| 5/5 [00:00<00:00, 118.78it/s, epoch=7, train loss=0.1428, train acc=0.97, val loss=0.1028, val acc=0.98, time=0.04]
# Epoch 8: 100%|██████████| 5/5 [00:00<00:00, 130.52it/s, epoch=8, train loss=0.1455, train acc=0.97, val loss=0.0990, val acc=0.98, time=0.04]
# Epoch 9: 100%|██████████| 5/5 [00:00<00:00, 131.90it/s, epoch=9, train loss=0.1367, train acc=0.97, val loss=0.0959, val acc=0.98, time=0.04]
# Epoch 10: 100%|██████████| 5/5 [00:00<00:00, 123.01it/s, epoch=10, train loss=0.1283, train acc=0.97, val loss=0.0933, val acc=0.98, time=0.04]
# Epoch 11: 100%|██████████| 5/5 [00:00<00:00, 120.40it/s, epoch=11, train loss=0.1333, train acc=0.97, val loss=0.0916, val acc=0.98, time=0.04]
# Epoch 12: 100%|██████████| 5/5 [00:00<00:00, 129.59it/s, epoch=12, train loss=0.1258, train acc=0.97, val loss=0.0901, val acc=0.98, time=0.04]
# Epoch 13: 100%|██████████| 5/5 [00:00<00:00, 128.56it/s, epoch=13, train loss=0.1325, train acc=0.97, val loss=0.0891, val acc=0.98, time=0.04]
# Epoch 14: 100%|██████████| 5/5 [00:00<00:00, 126.28it/s, epoch=14, train loss=0.1318, train acc=0.97, val loss=0.0884, val acc=0.98, time=0.04]
# Epoch 15: 100%|██████████| 5/5 [00:00<00:00, 129.63it/s, epoch=15, train loss=0.1313, train acc=0.97, val loss=0.0878, val acc=0.98, time=0.04]
# Epoch 16: 100%|██████████| 5/5 [00:00<00:00, 126.13it/s, epoch=16, train loss=0.1309, train acc=0.97, val loss=0.0874, val acc=0.98, time=0.04]
# Epoch 17: 100%|██████████| 5/5 [00:00<00:00, 133.76it/s, epoch=17, train loss=0.1312, train acc=0.97, val loss=0.0870, val acc=0.98, time=0.04]
# Epoch 18: 100%|██████████| 5/5 [00:00<00:00, 138.16it/s, epoch=18, train loss=0.1228, train acc=0.97, val loss=0.0865, val acc=0.98, time=0.04]
# Epoch 19: 100%|██████████| 5/5 [00:00<00:00, 129.90it/s, epoch=19, train loss=0.1304, train acc=0.97, val loss=0.0863, val acc=0.98, time=0.04]
# Epoch 20: 100%|██████████| 5/5 [00:00<00:00, 125.80it/s, epoch=20, train loss=0.1220, train acc=0.97, val loss=0.0858, val acc=0.98, time=0.04]
# Epoch 21: 100%|██████████| 5/5 [00:00<00:00, 124.64it/s, epoch=21, train loss=0.1434, train acc=0.97, val loss=0.0862, val acc=0.98, time=0.04]
# Epoch 22: 100%|██████████| 5/5 [00:00<00:00, 128.65it/s, epoch=22, train loss=0.1367, train acc=0.97, val loss=0.0863, val acc=0.98, time=0.04]
# Epoch 23: 100%|██████████| 5/5 [00:00<00:00, 126.99it/s, epoch=23, train loss=0.1288, train acc=0.97, val loss=0.0861, val acc=0.98, time=0.04]
# Epoch 24: 100%|██████████| 5/5 [00:00<00:00, 133.57it/s, epoch=24, train loss=0.1349, train acc=0.97, val loss=0.0861, val acc=0.98, time=0.04]
# Epoch 25: 100%|██████████| 5/5 [00:00<00:00, 135.64it/s, epoch=25, train loss=0.1284, train acc=0.97, val loss=0.0859, val acc=0.98, time=0.04]
# Epoch 26: 100%|██████████| 5/5 [00:00<00:00, 131.76it/s, epoch=26, train loss=0.1344, train acc=0.97, val loss=0.0860, val acc=0.98, time=0.04]
# Epoch 27: 100%|██████████| 5/5 [00:00<00:00, 135.52it/s, epoch=27, train loss=0.1276, train acc=0.97, val loss=0.0858, val acc=0.98, time=0.04]
# Epoch 28: 100%|██████████| 5/5 [00:00<00:00, 134.55it/s, epoch=28, train loss=0.1202, train acc=0.97, val loss=0.0854, val acc=0.98, time=0.04]
# Epoch 29: 100%|██████████| 5/5 [00:00<00:00, 131.61it/s, epoch=29, train loss=0.1198, train acc=0.97, val loss=0.0851, val acc=0.98, time=0.04]
# Epoch 30: 100%|██████████| 5/5 [00:00<00:00, 123.82it/s, epoch=30, train loss=0.1194, train acc=0.97, val loss=0.0848, val acc=0.98, time=0.04]
# Epoch 31: 100%|██████████| 5/5 [00:00<00:00, 130.17it/s, epoch=31, train loss=0.1338, train acc=0.97, val loss=0.0850, val acc=0.98, time=0.04]
# Epoch 32: 100%|██████████| 5/5 [00:00<00:00, 131.22it/s, epoch=32, train loss=0.1261, train acc=0.97, val loss=0.0849, val acc=0.98, time=0.04]
# Epoch 33: 100%|██████████| 5/5 [00:00<00:00, 124.37it/s, epoch=33, train loss=0.1335, train acc=0.97, val loss=0.0851, val acc=0.98, time=0.04]
# Epoch 34: 100%|██████████| 5/5 [00:00<00:00, 133.99it/s, epoch=34, train loss=0.1331, train acc=0.97, val loss=0.0851, val acc=0.98, time=0.04]
# Epoch 35: 100%|██████████| 5/5 [00:00<00:00, 127.05it/s, epoch=35, train loss=0.1183, train acc=0.97, val loss=0.0847, val acc=0.98, time=0.04]
# Epoch 36: 100%|██████████| 5/5 [00:00<00:00, 121.07it/s, epoch=36, train loss=0.1326, train acc=0.97, val loss=0.0849, val acc=0.98, time=0.04]
# Epoch 37: 100%|██████████| 5/5 [00:00<00:00, 125.82it/s, epoch=37, train loss=0.1325, train acc=0.97, val loss=0.0850, val acc=0.98, time=0.04]
# Epoch 38: 100%|██████████| 5/5 [00:00<00:00, 133.40it/s, epoch=38, train loss=0.1175, train acc=0.97, val loss=0.0846, val acc=0.98, time=0.04]
# Epoch 39: 100%|██████████| 5/5 [00:00<00:00, 124.97it/s, epoch=39, train loss=0.1174, train acc=0.97, val loss=0.0843, val acc=0.98, time=0.04]
# Epoch 40: 100%|██████████| 5/5 [00:00<00:00, 131.36it/s, epoch=40, train loss=0.1170, train acc=0.97, val loss=0.0841, val acc=0.98, time=0.04]
# Epoch 41: 100%|██████████| 5/5 [00:00<00:00, 127.49it/s, epoch=41, train loss=0.1246, train acc=0.97, val loss=0.0841, val acc=0.98, time=0.04]
# Epoch 42: 100%|██████████| 5/5 [00:00<00:00, 125.22it/s, epoch=42, train loss=0.1164, train acc=0.97, val loss=0.0838, val acc=0.98, time=0.04]
# Epoch 43: 100%|██████████| 5/5 [00:00<00:00, 128.21it/s, epoch=43, train loss=0.1311, train acc=0.97, val loss=0.0840, val acc=0.98, time=0.04]
# Epoch 44: 100%|██████████| 5/5 [00:00<00:00, 135.74it/s, epoch=44, train loss=0.1372, train acc=0.97, val loss=0.0845, val acc=0.98, time=0.04]
# Epoch 45: 100%|██████████| 5/5 [00:00<00:00, 131.66it/s, epoch=45, train loss=0.1219, train acc=0.97, val loss=0.0843, val acc=0.98, time=0.04]
# Epoch 46: 100%|██████████| 5/5 [00:00<00:00, 124.55it/s, epoch=46, train loss=0.1419, train acc=0.96, val loss=0.0849, val acc=0.98, time=0.04]
# Epoch 47: 100%|██████████| 5/5 [00:00<00:00, 132.95it/s, epoch=47, train loss=0.1230, train acc=0.97, val loss=0.0846, val acc=0.98, time=0.04]
# Epoch 48: 100%|██████████| 5/5 [00:00<00:00, 131.46it/s, epoch=48, train loss=0.1152, train acc=0.97, val loss=0.0841, val acc=0.98, time=0.04]
# Epoch 49: 100%|██████████| 5/5 [00:00<00:00, 127.65it/s, epoch=49, train loss=0.1223, train acc=0.97, val loss=0.0840, val acc=0.98, time=0.04]
# Epoch 50: 100%|██████████| 5/5 [00:00<00:00, 122.19it/s, epoch=50, train loss=0.1214, train acc=0.97, val loss=0.0840, val acc=0.98, time=0.04]
# Epoch 51: 100%|██████████| 5/5 [00:00<00:00, 130.05it/s, epoch=51, train loss=0.1287, train acc=0.97, val loss=0.0842, val acc=0.98, time=0.04]
# Epoch 52: 100%|██████████| 5/5 [00:00<00:00, 119.86it/s, epoch=52, train loss=0.1282, train acc=0.97, val loss=0.0842, val acc=0.98, time=0.04]
# Epoch 53: 100%|██████████| 5/5 [00:00<00:00, 125.65it/s, epoch=53, train loss=0.1286, train acc=0.97, val loss=0.0843, val acc=0.98, time=0.04]
# Epoch 54: 100%|██████████| 5/5 [00:00<00:00, 125.35it/s, epoch=54, train loss=0.1196, train acc=0.97, val loss=0.0841, val acc=0.98, time=0.04]
# Epoch 55: 100%|██████████| 5/5 [00:00<00:00, 127.25it/s, epoch=55, train loss=0.1199, train acc=0.97, val loss=0.0839, val acc=0.98, time=0.04]
# Epoch 56: 100%|██████████| 5/5 [00:00<00:00, 122.03it/s, epoch=56, train loss=0.1128, train acc=0.97, val loss=0.0834, val acc=0.98, time=0.04]
# Epoch 57: 100%|██████████| 5/5 [00:00<00:00, 130.91it/s, epoch=57, train loss=0.1269, train acc=0.97, val loss=0.0835, val acc=0.98, time=0.04]
# Epoch 58: 100%|██████████| 5/5 [00:00<00:00, 125.11it/s, epoch=58, train loss=0.1332, train acc=0.97, val loss=0.0839, val acc=0.98, time=0.04]
# Epoch 59: 100%|██████████| 5/5 [00:00<00:00, 126.58it/s, epoch=59, train loss=0.1120, train acc=0.97, val loss=0.0834, val acc=0.98, time=0.04]
# Epoch 60: 100%|██████████| 5/5 [00:00<00:00, 126.34it/s, epoch=60, train loss=0.1256, train acc=0.97, val loss=0.0836, val acc=0.98, time=0.04]
# Epoch 61: 100%|██████████| 5/5 [00:00<00:00, 132.42it/s, epoch=61, train loss=0.1375, train acc=0.96, val loss=0.0842, val acc=0.98, time=0.04]
# Epoch 62: 100%|██████████| 5/5 [00:00<00:00, 127.53it/s, epoch=62, train loss=0.1231, train acc=0.97, val loss=0.0841, val acc=0.98, time=0.04]
# Epoch 63: 100%|██████████| 5/5 [00:00<00:00, 134.09it/s, epoch=63, train loss=0.1162, train acc=0.97, val loss=0.0838, val acc=0.98, time=0.04]
# Epoch 64: 100%|██████████| 5/5 [00:00<00:00, 122.27it/s, epoch=64, train loss=0.1292, train acc=0.97, val loss=0.0840, val acc=0.98, time=0.04]
# Epoch 65: 100%|██████████| 5/5 [00:00<00:00, 122.94it/s, epoch=65, train loss=0.1220, train acc=0.97, val loss=0.0839, val acc=0.98, time=0.04]
# Epoch 66: 100%|██████████| 5/5 [00:00<00:00, 135.85it/s, epoch=66, train loss=0.1170, train acc=0.97, val loss=0.0836, val acc=0.98, time=0.04]
# Epoch 67: 100%|██████████| 5/5 [00:00<00:00, 137.17it/s, epoch=67, train loss=0.1163, train acc=0.97, val loss=0.0834, val acc=0.98, time=0.04]
# Epoch 68: 100%|██████████| 5/5 [00:00<00:00, 129.28it/s, epoch=68, train loss=0.1146, train acc=0.97, val loss=0.0832, val acc=0.98, time=0.04]
# Epoch 69: 100%|██████████| 5/5 [00:00<00:00, 125.95it/s, epoch=69, train loss=0.1090, train acc=0.97, val loss=0.0828, val acc=0.98, time=0.04]
# Epoch 70: 100%|██████████| 5/5 [00:00<00:00, 132.78it/s, epoch=70, train loss=0.1085, train acc=0.97, val loss=0.0825, val acc=0.98, time=0.04]
# Epoch 71: 100%|██████████| 5/5 [00:00<00:00, 133.77it/s, epoch=71, train loss=0.1150, train acc=0.97, val loss=0.0824, val acc=0.98, time=0.04]
# Epoch 72: 100%|██████████| 5/5 [00:00<00:00, 125.84it/s, epoch=72, train loss=0.1148, train acc=0.97, val loss=0.0823, val acc=0.98, time=0.04]
# Epoch 73: 100%|██████████| 5/5 [00:00<00:00, 125.17it/s, epoch=73, train loss=0.1286, train acc=0.97, val loss=0.0827, val acc=0.98, time=0.04]
# Epoch 74: 100%|██████████| 5/5 [00:00<00:00, 123.38it/s, epoch=74, train loss=0.1128, train acc=0.97, val loss=0.0824, val acc=0.98, time=0.04]
# Epoch 75: 100%|██████████| 5/5 [00:00<00:00, 130.31it/s, epoch=75, train loss=0.1139, train acc=0.97, val loss=0.0822, val acc=0.98, time=0.04]
# Epoch 76: 100%|██████████| 5/5 [00:00<00:00, 125.30it/s, epoch=76, train loss=0.1135, train acc=0.97, val loss=0.0822, val acc=0.98, time=0.04]
# Epoch 77: 100%|██████████| 5/5 [00:00<00:00, 130.26it/s, epoch=77, train loss=0.1066, train acc=0.97, val loss=0.0818, val acc=0.98, time=0.04]
# Epoch 78: 100%|██████████| 5/5 [00:00<00:00, 135.32it/s, epoch=78, train loss=0.1113, train acc=0.97, val loss=0.0818, val acc=0.98, time=0.04]
# Epoch 79: 100%|██████████| 5/5 [00:00<00:00, 126.04it/s, epoch=79, train loss=0.1061, train acc=0.97, val loss=0.0816, val acc=0.98, time=0.04]
# Epoch 80: 100%|██████████| 5/5 [00:00<00:00, 136.88it/s, epoch=80, train loss=0.1190, train acc=0.97, val loss=0.0819, val acc=0.98, time=0.04]
# Epoch 81: 100%|██████████| 5/5 [00:00<00:00, 126.19it/s, epoch=81, train loss=0.1053, train acc=0.97, val loss=0.0815, val acc=0.98, time=0.04]
# Epoch 82: 100%|██████████| 5/5 [00:00<00:00, 135.69it/s, epoch=82, train loss=0.1052, train acc=0.97, val loss=0.0813, val acc=0.98, time=0.04]
# Epoch 83: 100%|██████████| 5/5 [00:00<00:00, 123.67it/s, epoch=83, train loss=0.1047, train acc=0.97, val loss=0.0811, val acc=0.98, time=0.04]
# Epoch 84: 100%|██████████| 5/5 [00:00<00:00, 128.96it/s, epoch=84, train loss=0.1178, train acc=0.97, val loss=0.0813, val acc=0.98, time=0.04]
# Epoch 85: 100%|██████████| 5/5 [00:00<00:00, 132.93it/s, epoch=85, train loss=0.1043, train acc=0.97, val loss=0.0811, val acc=0.98, time=0.04]
# Epoch 86: 100%|██████████| 5/5 [00:00<00:00, 119.98it/s, epoch=86, train loss=0.1103, train acc=0.97, val loss=0.0812, val acc=0.98, time=0.04]
# Epoch 87: 100%|██████████| 5/5 [00:00<00:00, 128.28it/s, epoch=87, train loss=0.1104, train acc=0.97, val loss=0.0812, val acc=0.98, time=0.04]
# Epoch 88: 100%|██████████| 5/5 [00:00<00:00, 125.97it/s, epoch=88, train loss=0.1099, train acc=0.97, val loss=0.0812, val acc=0.98, time=0.04]
# Epoch 89: 100%|██████████| 5/5 [00:00<00:00, 123.46it/s, epoch=89, train loss=0.1156, train acc=0.97, val loss=0.0814, val acc=0.98, time=0.04]
# Epoch 90: 100%|██████████| 5/5 [00:00<00:00, 131.96it/s, epoch=90, train loss=0.1028, train acc=0.97, val loss=0.0812, val acc=0.98, time=0.04]
# Epoch 91: 100%|██████████| 5/5 [00:00<00:00, 126.46it/s, epoch=91, train loss=0.1196, train acc=0.97, val loss=0.0816, val acc=0.98, time=0.04]
# Epoch 92: 100%|██████████| 5/5 [00:00<00:00, 130.98it/s, epoch=92, train loss=0.1024, train acc=0.97, val loss=0.0811, val acc=0.98, time=0.04]
# Epoch 93: 100%|██████████| 5/5 [00:00<00:00, 133.17it/s, epoch=93, train loss=0.1063, train acc=0.97, val loss=0.0810, val acc=0.98, time=0.04]
# Epoch 94: 100%|██████████| 5/5 [00:00<00:00, 137.91it/s, epoch=94, train loss=0.1142, train acc=0.97, val loss=0.0813, val acc=0.98, time=0.04]
# Epoch 95: 100%|██████████| 5/5 [00:00<00:00, 125.21it/s, epoch=95, train loss=0.1133, train acc=0.97, val loss=0.0814, val acc=0.98, time=0.04]
# Epoch 96: 100%|██████████| 5/5 [00:00<00:00, 131.52it/s, epoch=96, train loss=0.1010, train acc=0.97, val loss=0.0810, val acc=0.98, time=0.04]
# Epoch 97: 100%|██████████| 5/5 [00:00<00:00, 135.98it/s, epoch=97, train loss=0.1182, train acc=0.97, val loss=0.0815, val acc=0.98, time=0.04]
# Epoch 98: 100%|██████████| 5/5 [00:00<00:00, 127.47it/s, epoch=98, train loss=0.1120, train acc=0.97, val loss=0.0815, val acc=0.98, time=0.04]
# Epoch 99: 100%|██████████| 5/5 [00:00<00:00, 135.66it/s, epoch=99, train loss=0.1188, train acc=0.97, val loss=0.0820, val acc=0.98, time=0.04]
# Epoch 100: 100%|██████████| 5/5 [00:00<00:00, 130.42it/s, epoch=100, train loss=0.1100, train acc=0.97, val loss=0.0818, val acc=0.98, time=0.04]
# Epoch 101: 100%|██████████| 5/5 [00:00<00:00, 122.29it/s, epoch=101, train loss=0.1119, train acc=0.97, val loss=0.0818, val acc=0.98, time=0.04]
# Epoch 102: 100%|██████████| 5/5 [00:00<00:00, 123.22it/s, epoch=102, train loss=0.1032, train acc=0.97, val loss=0.0815, val acc=0.98, time=0.04]
# Epoch 103: 100%|██████████| 5/5 [00:00<00:00, 130.03it/s, epoch=103, train loss=0.1082, train acc=0.97, val loss=0.0814, val acc=0.98, time=0.04]
# Epoch 104: 100%|██████████| 5/5 [00:00<00:00, 129.28it/s, epoch=104, train loss=0.1108, train acc=0.97, val loss=0.0816, val acc=0.98, time=0.04]
# Epoch 105: 100%|██████████| 5/5 [00:00<00:00, 125.72it/s, epoch=105, train loss=0.1037, train acc=0.97, val loss=0.0814, val acc=0.98, time=0.04]
# Epoch 106: 100%|██████████| 5/5 [00:00<00:00, 128.60it/s, epoch=106, train loss=0.1097, train acc=0.97, val loss=0.0814, val acc=0.98, time=0.04]
# Epoch 107: 100%|██████████| 5/5 [00:00<00:00, 132.22it/s, epoch=107, train loss=0.1023, train acc=0.97, val loss=0.0811, val acc=0.98, time=0.04]
# Epoch 108: 100%|██████████| 5/5 [00:00<00:00, 127.68it/s, epoch=108, train loss=0.0968, train acc=0.97, val loss=0.0807, val acc=0.98, time=0.04]
# Epoch 109: 100%|██████████| 5/5 [00:00<00:00, 125.25it/s, epoch=109, train loss=0.0965, train acc=0.97, val loss=0.0803, val acc=0.98, time=0.04]
# Epoch 110: 100%|██████████| 5/5 [00:00<00:00, 129.86it/s, epoch=110, train loss=0.0962, train acc=0.97, val loss=0.0800, val acc=0.98, time=0.04]
# Epoch 111: 100%|██████████| 5/5 [00:00<00:00, 130.84it/s, epoch=111, train loss=0.1143, train acc=0.97, val loss=0.0806, val acc=0.98, time=0.04]
# Epoch 112: 100%|██████████| 5/5 [00:00<00:00, 129.90it/s, epoch=112, train loss=0.0957, train acc=0.97, val loss=0.0802, val acc=0.98, time=0.04]
# Epoch 113: 100%|██████████| 5/5 [00:00<00:00, 122.81it/s, epoch=113, train loss=0.1008, train acc=0.97, val loss=0.0802, val acc=0.98, time=0.04]
# Epoch 114: 100%|██████████| 5/5 [00:00<00:00, 121.57it/s, epoch=114, train loss=0.1046, train acc=0.97, val loss=0.0804, val acc=0.98, time=0.04]
# Epoch 115: 100%|██████████| 5/5 [00:00<00:00, 130.02it/s, epoch=115, train loss=0.1104, train acc=0.97, val loss=0.0806, val acc=0.98, time=0.04]
# Epoch 116: 100%|██████████| 5/5 [00:00<00:00, 137.50it/s, epoch=116, train loss=0.1097, train acc=0.97, val loss=0.0809, val acc=0.98, time=0.04]
# Epoch 117: 100%|██████████| 5/5 [00:00<00:00, 130.54it/s, epoch=117, train loss=0.1014, train acc=0.97, val loss=0.0807, val acc=0.98, time=0.04]
# Epoch 118: 100%|██████████| 5/5 [00:00<00:00, 126.45it/s, epoch=118, train loss=0.0933, train acc=0.97, val loss=0.0803, val acc=0.98, time=0.04]
# Epoch 119: 100%|██████████| 5/5 [00:00<00:00, 119.55it/s, epoch=119, train loss=0.1020, train acc=0.97, val loss=0.0804, val acc=0.98, time=0.04]
# Prediction: 100%|██████████| 69/69 [00:00<00:00, 306.34it/s]

# %%
# 模型保存
torch.save(net, 'model_cnn_TP_FP.pkl')
# 模型加载
# model = torch.load('model_cnn.pkl')

# %%
def metrics_sklearn( y_pred_,y_valid):
    """模型对验证集和测试集结果的评分"""
    # 准确率
    accuracy = accuracy_score(y_valid, y_pred_)
    print('Accuracy：%.6f%%' % (accuracy * 100))

    # 精准率
    precision = precision_score(y_valid, y_pred_)
    print('Precision：%.6f%%' % (precision * 100))

    # 召回率
    recall = recall_score(y_valid, y_pred_)
    # print(y_valid)
    # print('-----------------------------')
    # print(y_pred_)
    print('Recall：%.6f%%' % (recall * 100))

    # F1值
    f1 = f1_score(y_valid, y_pred_)
    print('F1：%.6f%%' % (f1 * 100))

    # auc曲线下面积
    auc = roc_auc_score(y_valid, y_pred_)
    print('AUC：%.6f%%' % (auc * 100))

    # ks值
    fpr, tpr, thresholds = roc_curve(y_valid, y_pred_)
    ks = max(abs(fpr - tpr))
    print('KS：%.6f%%' % (ks * 100))
